# %% [markdown]
# #### method 2

# %%
root = '/Users/jonathanlittel/Dropbox/work/Mazazul/evaluamango/label_app/images/'
root = '/Users/jonathanlittel/Dropbox/work/Mazazul/evaluamango/'

path1 = 'data_leaf/train/1. Quercus suber/'    
path2 = 'data_leaf/validation/'

# %%
allImages =

# %%
import matplotlib.pyplot as plt
import os
from PIL import Image
category=[]
plt.ion()


listing = os.listdir(root + path1)    

for file in listing:
    im = Image.open(root + path1 + file)    
    im.resize((50,50))                # need to do some more processing here             
    im.save(root + path2 + file, "JPEG")

# %% [markdown]
# #### method 3

# %%
import matplotlib.pyplot as plt
import os
category=[]
plt.ion()

for i,image in enumerate(allImages):
    plt.imshow(image)
    plt.pause(0.05)
    category.append(raw_input('category: '))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-4cbd36314be6> in <module>()
#       3 plt.ion()
#       4
# ----> 5 for i,image in enumerate(allImages):
#       6     plt.imshow(image)
#       7     plt.pause(0.05)
#
# NameError: name 'allImages' is not defined

# %% [markdown]
# #### method 3 modified and functional

# %%
import matplotlib.pyplot as plt
category=[]
plt.ion()

listing = os.listdir(root + path1)  

for i in listing:
    image = Image.open(root + path1 + i)
    plt.imshow(image)
    plt.pause(0.5)
    # category.append(input('category: '))
    plt.pause(0.5)

# %%
listing = os.listdir(root + path1)  
listing
# Out:
# ['iPAD2_C01_EX01.JPG',
#  'iPAD2_C01_EX02.JPG',
#  'iPAD2_C01_EX03.JPG',
#  'iPAD2_C01_EX04.JPG',
#  'iPAD2_C01_EX05.JPG',
#  'iPAD2_C01_EX06.JPG',
#  'iPAD2_C01_EX07.JPG',
#  'iPAD2_C01_EX08.JPG',
#  'iPAD2_C01_EX09.JPG',
#  'iPAD2_C01_EX10.JPG',
#  'iPAD2_C01_EX11.JPG',
#  'iPAD2_C01_EX12.JPG']

# %%
for file in listing:
  print(file)
  # Image.open(root + path1 + listing)
# Out:
# iPAD2_C01_EX01.JPG
# iPAD2_C01_EX02.JPG
# iPAD2_C01_EX03.JPG
# iPAD2_C01_EX04.JPG
# iPAD2_C01_EX05.JPG
# iPAD2_C01_EX06.JPG
# iPAD2_C01_EX07.JPG
# iPAD2_C01_EX08.JPG
# iPAD2_C01_EX09.JPG
# iPAD2_C01_EX10.JPG
# iPAD2_C01_EX11.JPG
# iPAD2_C01_EX12.JPG

# %%
os.getcwd()
# Out:
# '/Users/jonathanlittel/Dropbox/work/mazazul/evaluamango'
